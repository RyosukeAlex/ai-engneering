# %% [markdown]
# ### MNISTの手描き文字を推測するNNモデルを実装する。

# %%
# ===== Library Import =====
import pandas as pd
import numpy as np
import os, sys
sys.path.append('/Users/ryosuke/ai-engneering/dl_from_scratch')
from dataset.mnist import load_mnist

# %%
'''
from dataset . mnist import load_mnist
     └──┬──┘   └─┬─┘        └────┬────┘
   フォルダ名  ファイル名      その中の関数名
   dataset/   mnist.py       def load_mnist
'''
# Out:
# '\nfrom dataset . mnist import load_mnist\n     └──┬──┘   └─┬─┘        └────┬────┘\n   フォルダ名  ファイル名      その中の関数名\n   dataset/   mnist.py       def load_mnist\n'

# %%
print(x_train.shape)
print(x_test.shape)
print(t_train.shape)
print(t_test.shape)
# Out:
# (60000, 784)
# (10000, 784)
# (60000,)
# (10000,)
