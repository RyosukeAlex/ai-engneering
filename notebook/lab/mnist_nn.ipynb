# %% [markdown]
# ### MNISTの手描き文字を推測するNNモデルを実装する。

# %%
# ===== Library Import =====
import pandas as pd
import numpy as np
import os, sys
sys.path.append('/Users/ryosuke/ai-engneering/dl_from_scratch')
from dataset.mnist import load_mnist
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 6
#       2 import pandas as pd
#       3 import numpy as np
#       4 import os, sys
#       5 sys.path.append('/Users/ryosuke/ai-engneering/dl_from_scratch')
# ----> 6 from dataset.mnist import load_mnist
#
# ModuleNotFoundError: No module named 'dataset'

# %%
'''
from dataset . mnist import load_mnist
     └──┬──┘   └─┬─┘        └────┬────┘
   フォルダ名  ファイル名      その中の関数名
   dataset/   mnist.py       def load_mnist
'''
# Out:
# '\nfrom dataset . mnist import load_mnist\n     └──┬──┘   └─┬─┘        └────┬────┘\n   フォルダ名  ファイル名      その中の関数名\n   dataset/   mnist.py       def load_mnist\n'
