# %% [markdown]
# ### MNISTの手描き文字を推測するNNモデルを実装する。

# %%
# ===== Library Import =====
import pandas as pd
import numpy as np
import os, sys
from PIL import Image

# 基準となるフォルダを ai-engneering に変更
sys.path.append('/Users/ryosuke/ai-engneering')

# datasetフォルダの中の、dl_from_scratchフォルダの中の、mnistを指定
from dataset.dl_from_scratch.mnist import load_mnist

# %%
'''
from dataset . mnist import load_mnist
     └──┬──┘   └─┬─┘        └────┬────┘
   フォルダ名  ファイル名      その中の関数名
   dataset/   mnist.py       def load_mnist
'''
# Out:
# '\nfrom dataset . mnist import load_mnist\n     └──┬──┘   └─┬─┘        └────┬────┘\n   フォルダ名  ファイル名      その中の関数名\n   dataset/   mnist.py       def load_mnist\n'

# %%
# MNISTの画像データを確認してみる
def img_show(img):
    pil_img = Image.fromarray(np.uint8(img))
    pil_img.show()

(x_train, t_train), (x_test, t_test) = load_mnist(flatten=True, normalize=False)

img = x_train[0]
label = t_train[0]
print(label) 

print(img.shape)
img = img.reshape(28, 28)
print(img.shape)

img_show(img)
# Out:
# 5
# (784,)
# (28, 28)
