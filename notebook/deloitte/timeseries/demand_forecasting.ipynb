# %%
##### データの読み込み #####
import pandas as pd
import numpy as np
import seaborn as sns

df = pd.read_csv('/Users/ryosuke/ai-engneering/dataset/mayonnaise/demand_forecasting.csv')

# %%
##### データの中身の確認 #####
df.head(20)
# Out:
#           Date Store ID Product ID     Category Region  Inventory Level  \
# 0   2022-01-01     S001      P0001  Electronics  North              195
# 1   2022-01-01     S001      P0002     Clothing  North              117
# 2   2022-01-01     S001      P0003     Clothing  North              247
# 3   2022-01-01     S001      P0004  Electronics  North              139
# 4   2022-01-01     S001      P0005    Groceries  North              152
# 5   2022-01-01     S001      P0006         Toys  North              209
# 6   2022-01-01     S001      P0007    Groceries  North              118
# 7   2022-01-01     S001      P0008  Electronics  North              244
# 8   2022-01-01     S001      P0009     Clothing  North              115
# 9   2022-01-01     S001      P0010    Furniture  North              192
# 10  2022-01-01     S001      P0011    Furniture  North              215
# 11  2022-01-01     S001      P0012    Groceries  North              289
# ...

# %%
##### データ型の確認 #####
print(df.dtypes)
# Out:
# Date                      str
# Store ID                  str
# Product ID                str
# Category                  str
# Region                    str
# Inventory Level         int64
# Units Sold              int64
# Units Ordered           int64
# Price                 float64
# Discount                int64
# Weather Condition         str
# Promotion               int64
# Competitor Pricing    float64
# Seasonality               str
# Epidemic                int64
# Demand                  int64
# dtype: object

# %%
##### 'Grocerios'に絞ってdfを再度作成する #####
df_groceries = df[df['Category'] == 'Groceries'].copy()
df_groceries.head()
# Out:
#           Date Store ID Product ID   Category Region  Inventory Level  \
# 4   2022-01-01     S001      P0005  Groceries  North              152
# 6   2022-01-01     S001      P0007  Groceries  North              118
# 11  2022-01-01     S001      P0012  Groceries  North              289
# 13  2022-01-01     S001      P0014  Groceries  North              252
# 15  2022-01-01     S001      P0016  Groceries  North              103
#
#     Units Sold  Units Ordered  Price  Discount Weather Condition  Promotion  \
# 4           65            271  54.41         0             Snowy          0
# 6           81            335  23.27         5             Snowy          0
# 11         121            215  84.48         0             Snowy          0
# 13         121            479  80.13        10             Snowy          1
# 15          78            372  38.79        10             Snowy          0
#
#     Competitor Pricing Seasonality  Epidemic  Demand
# ...

# %%
##### データ数の確認 #####
print(df_groceries.shape)
# Out:
# (30400, 16)

# %%
##### データ型の変換 #####
df_groceries['Date'] = pd.to_datetime(df_grocerios['Date'])

# %%
##### StoreIDとDateIDが同一なレコードを集計する #####
df_groceries = (
    df_groceries.groupby(['Date', 'StoreID'], as_index=False)
    .agg({
        'Inventory Level': 'sum',
        'Units Sold': 'sum',
        'Units Ordered': 'sum',

    })
)
#### どのカラムまでを'sum'するかは、データの内容をもって判断する必要があるので、次に実施する際にはここから ###
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 3
#       1 ##### StoreIDとDateIDが同一なレコードを集計する #####
#       2 df_groceries = (
# ----> 3     df_groceries.groupby(['Date', 'StoreID'], as_index=False)
#       4     .agg({
#       5         'Inventory Level': 'sum',
#       6         'Units Sold': 'sum',
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.13/site-packages/pandas/util/_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# ...
